# %% [markdown]
# <a href="https://colab.research.google.com/github/atharvsalokhe30/Deep_Learning-_project_practice/blob/main/Simple_Linear_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('score.csv')

df
# Out:
#     Hours  Scores
# 0     2.5      21
# 1     5.1      47
# 2     3.2      27
# 3     8.5      75
# 4     3.5      30
# 5     1.5      20
# 6     9.2      88
# 7     5.5      60
# 8     8.3      81
# 9     2.7      25
# 10    7.7      85
# 11    5.9      62
# 12    4.5      41
# 13    3.3      42
# 14    1.1      17
# 15    8.9      95
# 16    2.5      30
# 17    1.9      24
# 18    6.1      67
# 19    7.4      69
# 20    2.7      30
# 21    4.8      54
# 22    3.8      35
# 23    6.9      76
# 24    7.8      86

# %%
df.describe()
# Out:
#            Hours     Scores
# count  25.000000  25.000000
# mean    5.012000  51.480000
# std     2.525094  25.286887
# min     1.100000  17.000000
# 25%     2.700000  30.000000
# 50%     4.800000  47.000000
# 75%     7.400000  75.000000
# max     9.200000  95.000000

# %%
df.mean() # Find Average
# Out:
# Hours      5.012
# Scores    51.480
# dtype: float64

# %%
df.median() #Find Median Value
# Out:
# Hours      4.8
# Scores    47.0
# dtype: float64

# %%
df.mode() #Find Mode Frequently
# Out:
#    Hours  Scores
# 0    2.5    30.0
# 1    2.7     NaN

# %%
df.std()
# Out:
# Hours      2.525094
# Scores    25.286887
# dtype: float64

# %%
df.corr()
# Out:
#            Hours    Scores
# Hours   1.000000  0.976191
# Scores  0.976191  1.000000

# %%
df.cov()
# Out:
#           Hours      Scores
# Hours    6.3761   62.331500
# Scores  62.3315  639.426667

# %%
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.histplot(df['Hours'], bins=10, kde=True)
plt.title('Distribution of Hours Studied')
# Out:
# Text(0.5, 1.0, 'Distribution of Hours Studied')

# %%
plt.subplot(1, 2,2)
sns.histplot(df['Scores'], bins=10, kde=True)
plt.title('Distribution of Exam Scores')
plt.show()

# %%
# Boxplots
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.boxplot(y=df['Hours'])
plt.title('Boxplot of Hours Studied' )
# Out:
# Text(0.5, 1.0, 'Boxplot of Hours Studied')

# %%
plt.subplot(1, 2, 2)
sns.boxplot(y=df['Scores'])
plt.title('Boxplot of Exam Scores')
plt.show()

# %%
# Scatter Plot
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Hours', y='Scores', data=df)
plt.title('Scatter Plot of Hours Studied vs Exam Score' )
plt.xlabel('Hours Studied' )
plt.ylabel('Exam Score')
plt.show()

# %%
# Correlation
correlation = df['Hours' ].corr(df['Scores'])
print(f'Correlation coefficient between Hours Studied and Exam Score: {correlation}')
# Out:
# Correlation coefficient between Hours Studied and Exam Score: 0.9761906560220887

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Define a custom color palette
colors = sns.color_palette("Spectral", as_cmap=True)

# Calculate the correlation matrix
correlation_matrix = df.corr()

# Plot the heatmap
plt.figure(figsize=(8, 6))
sns. heatmap(correlation_matrix, annot=True, cmap=colors)
plt.title('Correlation Heatmap with Custom Colors')
plt.show()

# %%
Y = df['Scores' ]

print("X (Features):")
print(X)
print("\nY (Target Variable):")
print(Y)

# Split the dataset into X (features) and Y (target variable)
X = df[['Hours']] # Features (as a DataFrame)
# Target variable (as a Series)
# Out:
# X (Features):
#     Hours
# 0     2.5
# 1     5.1
# 2     3.2
# 3     8.5
# 4     3.5
# 5     1.5
# 6     9.2
# 7     5.5
# 8     8.3
# 9     2.7
# 10    7.7
# 11    5.9
# 12    4.5
# 13    3.3
# 14    1.1
# 15    8.9
# 16    2.5
# 17    1.9
# 18    6.1
# 19    7.4
# 20    2.7
# 21    4.8
# 22    3.8
# 23    6.9
# 24    7.8
#
# Y (Target Variable):
# 0     21
# 1     47
# 2     27
# 3     75
# 4     30
# 5     20
# 6     88
# 7     60
# 8     81
# 9     25
# 10    85
# 11    62
# 12    41
# 13    42
# 14    17
# 15    95
# 16    30
# 17    24
# 18    67
# 19    69
# 20    30
# 21    54
# 22    35
# 23    76
# 24    86
# Name: Scores, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
# Split the data into training and testing sets (80% training, 20% testing)
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

print("X_train:")
print(X_train)
print("\nX_test:")
print(X_test)
print("\nY_train:")
print(Y_train)
print("\nY_test:")
print(Y_test)
# Out:
# X_train:
#     Hours
# 9     2.7
# 13    3.3
# 1     5.1
# 22    3.8
# 5     1.5
# 2     3.2
# 12    4.5
# 15    8.9
# 3     8.5
# 4     3.5
# 20    2.7
# 17    1.9
# 21    4.8
# 18    6.1
# 24    7.8
# 7     5.5
# 10    7.7
# 14    1.1
# 19    7.4
# 6     9.2
#
# X_test:
#     Hours
# 8     8.3
# 16    2.5
# 0     2.5
# 23    6.9
# 11    5.9
#
# Y_train:
# 9     25
# 13    42
# 1     47
# 22    35
# 5     20
# 2     27
# 12    41
# 15    95
# 3     75
# 4     30
# 20    30
# 17    24
# 21    54
# 18    67
# 24    86
# 7     60
# 10    85
# 14    17
# 19    69
# 6     88
# Name: Scores, dtype: int64
#
# Y_test:
# 8     81
# 16    30
# 0     21
# 23    76
# 11    62
# Name: Scores, dtype: int64

# %%
# Create a LinearRegression model
model = LinearRegression() # This line initializes a new instance of the LinearRegressic

# Train the model on the training data
model.fit(X_train, Y_train) # This trains the model by finding the best-fit line that min

# Display the coefficients
print(f'Intercept: {model.intercept_}')
print(f'Coefficient: {model.coef_[0]}')
# Out:
# Intercept: 2.826892353899737
# Coefficient: 9.682078154455697

# %%
# Make predictions on the testing set
Y_pred = model.predict(X_test)

# Display Actual values
print("Actual Values:")
print(Y_test)
# Display the predictions
print("Predictions:")
print(Y_pred)
# Out:
# Actual Values:
# 8     81
# 16    30
# 0     21
# 23    76
# 11    62
# Name: Scores, dtype: int64
# Predictions:
# [83.18814104 27.03208774 27.03208774 69.63323162 59.95115347]

# %%
# Calculate Mean Squared Error (MSE) and R-squared (R2) score
mse = mean_squared_error(Y_test, Y_pred)
r2 = r2_score(Y_test, Y_pred)

print(f'Mean Squared Error: {mse}')
print(f'R-squared: {r2}')
# Out:
# Mean Squared Error: 18.943211722315272
# R-squared: 0.9678055545167994
