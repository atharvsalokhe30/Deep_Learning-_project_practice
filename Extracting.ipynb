# %% [markdown]
# <a href="https://colab.research.google.com/github/atharvsalokhe30/Deep_Learning-_project_practice/blob/main/Extracting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Load the dataset
tesla_df = pd.read_csv('/content/Tesla_dataset.csv')

# Convert 'Date' column to datetime objects
tesla_df['Date'] = pd.to_datetime(tesla_df['Date'])

# Extract the year
Year = tesla_df['Date'].dt.year

# %%
column_name = 'DAX Formula'

# %%
Month = tesla_df['Date'].dt.month

# %%
df=pd.read_csv('Tesla_dataset.csv')

df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2010-06-29    1.266667    1.666667    1.169333    1.592667    1.592667
# 1     2010-06-30    1.719333    2.028000    1.553333    1.588667    1.588667
# 2     2010-07-01    1.666667    1.728000    1.351333    1.464000    1.464000
# 3     2010-07-02    1.533333    1.540000    1.247333    1.280000    1.280000
# 4     2010-07-06    1.333333    1.333333    1.055333    1.074000    1.074000
# ...          ...         ...         ...         ...         ...         ...
# 3500  2024-05-24  174.839996  180.080002  173.729996  179.240005  179.240005
# 3501  2024-05-28  176.399994  178.250000  173.160004  176.750000  176.750000
# 3502  2024-05-29  174.190002  178.149994  173.929993  176.190002  176.190002
# 3503  2024-05-30  178.580002  182.669998  175.380005  178.789993  178.789993
# 3504  2024-05-31  178.500000  180.320007  173.820007  178.080002  178.080002
#
#          Volume
# 0     281494500
# ...

# %%
Year = tesla_df['Date'].dt.year

# %%
df['Date'] = pd.to_datetime(df['Date'])
Year = df['Date'].dt.year
